# %% [markdown]
# # How to use widget in Jupyter Notebook

# %% [markdown]
# ## The widget in Jupyter Notebook can be simply used by the ipywidgets library. One can import the library as: <br>
# ```python
# import ipywidgets as widgets
# ```

# %%
import ipywidgets as widgets

# %% [markdown]
# ## A example to show the Sine function

# %% [markdown]
# ## Here is a interactive figure for y=sin(wx + b)

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import IntSlider
from matplotlib import rc

rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

x = np.linspace(0, 2 * np.pi, 2000)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot(x, np.sin(x),'r-')
ax.grid(True)
plt.xlim(0,6)
plt.title(r"Function $sin(wx+b)$", fontsize=15)

def update(w=IntSlider(value=10, min=-10, max=10), b=IntSlider(value=0.0, min=-10, max=10)):
    line.set_ydata(np.sin(w * x + b))
    fig.canvas.draw_idle()

widgets.interact(update);
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(IntSlider(value=10, description='w', max=10, min=-10), IntSlider(value=0, description='b…
